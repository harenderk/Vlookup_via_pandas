# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\Sonu\\Desktop\\python\\data science\\practice\\superstore_dataset2011-2015.csv')

# %%
df.tail()
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594    MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857  MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Dra�
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Ju�rez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %%
for c in df.columns:
    print(c)
# Out:
# Row ID
# Order ID
# Order Date
# Ship Date
# Ship Mode
# Customer ID
# Customer Name
# Segment
# City
# State
# Country
# Postal Code
# Market
# Region
# Product ID
# Category
# Sub-Category
# Product Name
# Sales
# Quantity
# Discount
# Profit
# Shipping Cost
# Order Priority

# %%
c = list(df.columns)
print(c)
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority']

# %%
data_cols  = ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority']

# %%
df = df.reindex(columns=data_cols) # rearrange new colums

# %%
data_cols1 = ['Customer ID', 'Customer Name']

# %%
data = df[data_cols1]

# %%
data.head()
# Out:
#   Customer ID    Customer Name
# 0    TB-11280  Toby Braunhardt
# 1    JH-15985      Joseph Holt
# 2      AT-735    Annie Thurman
# 3    EM-14140     Eugene Moren
# 4    JH-15985      Joseph Holt

# %%
data1 = df.merge(data, on ='Customer ID',how='left')

# %%
data1.head()
# Out:
#    Row ID      Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433  AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   42433  AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 2   42433  AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 3   42433  AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 4   42433  AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
#
#    Customer Name_x   Segment         City        State  ... Sub-Category  \
# 0  Toby Braunhardt  Consumer  Constantine  Constantine  ...      Storage
# 1  Toby Braunhardt  Consumer  Constantine  Constantine  ...      Storage
# 2  Toby Braunhardt  Consumer  Constantine  Constantine  ...      Storage
# 3  Toby Braunhardt  Consumer  Constantine  Constantine  ...      Storage
# 4  Toby Braunhardt  Consumer  Constantine  Constantine  ...      Storage
#
#           Product Name  Sales Quantity Discount  Profit Shipping Cost  \
# ...

# %%
d = list(data1.columns)
print(d)
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name_x', 'Segment', 'City', 'State', 'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Unnamed: 0', 'Customer Name_y']

# %%
data_col = ['Order ID', 'Order Date','Customer ID', 'Customer Name_x', 'Segment', 'Country','Sales', 'Quantity']

# %%
d = data1[data_col]
d.head()
# Out:
#        Order ID Order Date Customer ID  Customer Name_x   Segment  Country  \
# 0  AG-2011-2040   1/1/2011    TB-11280  Toby Braunhardt  Consumer  Algeria
# 1  AG-2011-2040   1/1/2011    TB-11280  Toby Braunhardt  Consumer  Algeria
# 2  AG-2011-2040   1/1/2011    TB-11280  Toby Braunhardt  Consumer  Algeria
# 3  AG-2011-2040   1/1/2011    TB-11280  Toby Braunhardt  Consumer  Algeria
# 4  AG-2011-2040   1/1/2011    TB-11280  Toby Braunhardt  Consumer  Algeria
#
#    Sales  Quantity
# 0  408.3         2
# 1  408.3         2
# 2  408.3         2
# 3  408.3         2
# 4  408.3         2

# %%
d.to_csv('store_data1.csv')
